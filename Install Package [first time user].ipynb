# %% [markdown]
# # All needed packages for CoA H+T costs calculation

# %% [markdown]
# ### Preparation:install needed package

# %%
# a handy trick to get rid of deprecation warnings
import warnings 
warnings.filterwarnings(action= 'ignore')

# %%
### preferred installation way: 

# !conda install -c conda-forge --yes census==0.8.17
# !conda install -c conda-forge --yes geopandas==0.12.1
# !conda install -c conda-forge --yes pandas==1.5.2
# !conda install -c conda-forge --yes numpy==1.23.5
# !conda install -c conda-forge --yes gdal==3.5.3

# !pip install us==2.0.2
# !pip install gtfs_kit==5.2.3
# !conda install -c conda-forge --yes openpyxl==3.0.10
# !conda install -c conda-forge --yes shapely==1.8.5
# !conda install -c conda-forge --yes haversine==2.7.0
# !pip install ipfn==1.4.4
# !pip install matplotlib-scalebar==0.8.1
# !pip install palettable==3.3.0
# !pip install legendgram==0.0.3
# !pip install dataframe-image==0.1.3
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\minyu\anaconda3\envs\htcosts
#
#   added / updated specs:
#     - census==0.8.17
#
#
# The following NEW packages will be INSTALLED:
#
#   brotlipy           conda-forge/win-64::brotlipy-0.7.0-py310h8d17308_1005
#   census             conda-forge/noarch::census-0.8.17-pyhd8ed1ab_0
#   certifi            conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   charset-normalizer conda-forge/noarch::charset-normalizer-2.1.1-pyhd8ed1ab_0
#   cryptography       conda-forge/win-64::cryptography-38.0.4-py310h6e82f81_0
#   future             conda-forge/noarch::future-0.18.2-pyhd8ed1ab_6
#   pyopenssl          conda-forge/noarch::pyopenssl-22.1.0-pyhd8ed1ab_0
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyh0701188_6
#   requests           conda-forge/noarch::requests-2.28.1-pyhd8ed1ab_1
#   urllib3            conda-forge/noarch::urllib3-1.26.13-pyhd8ed1ab_0
# ...

# %%
### If you want to try an alternative installation OR the preferred isntallation approach above does not work well,
### run the following code after removing the "#" in front of each line below)


#!pip install us==2.0.2
#!pip install census==0.8.17
#!pip install gtfs_kit==5.2.3
#!pip install matplotlib-scalebar==0.8.1
#!pip install openpyxl==3.0.10
#!pip install shapely==1.8.5
#!pip install ipfn==1.4.4
#!pip install haversine==2.7.0
#!pip install palettable==3.3.0
#!pip install legendgram==0.0.3
#!pip install dataframe-image==0.1.3
